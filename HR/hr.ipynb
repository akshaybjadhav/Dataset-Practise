# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(df['OverTime'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %%
sns.countplot(df['MaritalStatus'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(df['JobRole'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %%
sns.countplot(df['Gender'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['EducationField'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %%
sns.countplot(df['Department'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
sns.countplot(df['BusinessTravel'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
sns.countplot(df['OverTime'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(df['TotalWorkingYears'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='count'>

# %%
sns.countplot(df['Education'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
sns.countplot(df['NumCompaniesWorked'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['DistanceFromHome'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='count'>

# %%
#####################################################################

# %%
data = df.copy()

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials

# %%
data.head(3)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
cat = ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 
       'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
dummy = pd.get_dummies(data[cat],drop_first=True)

# %%
data = pd.concat([dummy,data],axis=1)
data.head()
# Out:
#    Attrition_Yes  BusinessTravel_Travel_Frequently  \
# 0              1                                 0
# 1              0                                 1
# 2              1                                 0
# 3              0                                 1
# 4              0                                 0
#
#    BusinessTravel_Travel_Rarely  Department_Research & Development  \
# 0                             1                                  0
# 1                             0                                  1
# 2                             1                                  1
# 3                             0                                  1
# 4                             1                                  1
#
#    Department_Sales  EducationField_Life Sciences  EducationField_Marketing  \
# 0                 1                             1                         0
# 1                 0                             1                         0
# ...

# %%
data.drop(columns=cat,axis=1,inplace=True)

# %%
data.head()
# Out:
#    Attrition_Yes  BusinessTravel_Travel_Frequently  \
# 0              1                                 0
# 1              0                                 1
# 2              1                                 0
# 3              0                                 1
# 4              0                                 0
#
#    BusinessTravel_Travel_Rarely  Department_Research & Development  \
# 0                             1                                  0
# 1                             0                                  1
# 2                             1                                  1
# 3                             0                                  1
# 4                             1                                  1
#
#    Department_Sales  EducationField_Life Sciences  EducationField_Marketing  \
# 0                 1                             1                         0
# 1                 0                             1                         0
# ...

# %%
data.rename(columns={'Attrition_Yes':'Attrition'},inplace=True)
data.head(2)
# Out:
#    Attrition  BusinessTravel_Travel_Frequently  BusinessTravel_Travel_Rarely  \
# 0          1                                 0                             1
# 1          0                                 1                             0
#
#    Department_Research & Development  Department_Sales  \
# 0                                  0                 1
# 1                                  1                 0
#
#    EducationField_Life Sciences  EducationField_Marketing  \
# 0                             1                         0
# 1                             1                         0
#
#    EducationField_Medical  EducationField_Other  \
# 0                       0                     0
# 1                       0                     0
#
#    EducationField_Technical Degree  ...  RelationshipSatisfaction  \
# 0                                0  ...                         1
# 1                                0  ...                         4
#
# ...

# %%
x = data.drop(columns=['Attrition'],axis=1)
y = data['Attrition']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20)

# %%
lc = LGBMClassifier()
lc.fit(x_train,y_train)
y_predict = lc.predict(x_test)
print(accuracy_score(y_test,y_predict))
print(confusion_matrix(y_test,y_predict))
print(classification_report(y_test,y_predict))
# Out:
# 0.8503401360544217
# [[234   6]
#  [ 38  16]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91       240
#            1       0.73      0.30      0.42        54
#
#     accuracy                           0.85       294
#    macro avg       0.79      0.64      0.67       294
# weighted avg       0.84      0.85      0.82       294

# %%
# defining parameters for LGB
space = {
    'learning_rate': hp.loguniform('learning_rate', np.log(0.001), np.log(0.3)),
    'n_estimators': hp.quniform('n_estimators', 50, 1200, 25),
    'max_depth': hp.quniform('max_depth', 1, 15, 1),
    'num_leaves': hp.quniform('num_leaves', 10, 150, 1),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.3, 1.0), 
    'feature_fraction': hp.uniform('feature_fraction', .3, 1.0),
    'reg_lambda': hp.uniform('reg_lambda', 0.0, 1.0),
    'reg_alpha': hp.uniform('reg_alpha', 0.0, 1.0),
    'min_split_gain': hp.uniform('min_split_gain', 0.0001, 0.1)
}

space['max_depth']

# %%
def objective(space):
    model = LGBMClassifier(learning_rate = space['learning_rate'],
                          n_estimators=space['n_estimators'],
                          max_depth=space['max_depth'],
                          num_leaves=space['num_leaves'],
                          colsample_bytree=space['colsample_bytree'],
                          feature_fraction = space['feature_fraction'],
                          reg_lambda=space['reg_lambda'],
                          reg_alpha=space['reg_alpha'],
                          min_split_gain=space['min_split_gain'])
    lc.fit(x_train,y_train)
    y_predict=lc.predict(x_test)
    accuracy = accuracy_score(y_test,y_predict)
    return {'status':STATUS_OK,'loss':-accuracy,'accuracy':accuracy}

# %%
trials = Trials()
best = fmin(fn=objective,space=space,algo=tpe.suggest,max_evals=150,trials=trials)
best
# Out:
# 100%|█████████████████████████████████████████████| 150/150 [01:05<00:00,  2.30trial/s, best loss: -0.8503401360544217]
# {'colsample_bytree': 0.5759290579266231,
#  'feature_fraction': 0.43602755834725593,
#  'learning_rate': 0.019977112544625215,
#  'max_depth': 7.0,
#  'min_split_gain': 0.09723422629285966,
#  'n_estimators': 400.0,
#  'num_leaves': 115.0,
#  'reg_alpha': 0.9147667479952429,
#  'reg_lambda': 0.44575408011576134}

# %%
lc = LGBMClassifier(colsample_bytree=best['colsample_bytree'],feature_fraction=best['feature_fraction'],
                    learning_rate=best['learning_rate'],max_depth=int(best['max_depth']),
                   min_split_gain=best['min_split_gain'],n_estimators=int(best['n_estimators']),
                   num_leaves=int(best['num_leaves']),reg_alpha=best['reg_alpha'],reg_lambda=best['reg_lambda'])
lc.fit(x_train,y_train)
y_predict = lc.predict(x_test)
print(accuracy_score(y_test,y_predict))
print(confusion_matrix(y_test,y_predict))
print(classification_report(y_test,y_predict))
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.43602755834725593, colsample_bytree=0.5759290579266231 will be ignored. Current value: feature_fraction=0.43602755834725593
# 0.8469387755102041
# [[233   7]
#  [ 38  16]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91       240
#            1       0.70      0.30      0.42        54
#
#     accuracy                           0.85       294
#    macro avg       0.78      0.63      0.66       294
# weighted avg       0.83      0.85      0.82       294

# %%
##################################################################################

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
age = pd.DataFrame(df.groupby('Age')[["MonthlyIncome","Education","JobLevel","JobInvolvement","PerformanceRating",
                                     "JobSatisfaction","EnvironmentSatisfaction","RelationshipSatisfaction",
                                     "WorkLifeBalance","DailyRate","MonthlyRate"]].mean())
age.head()
# Out:
#      MonthlyIncome  Education  JobLevel  JobInvolvement  PerformanceRating  \
# Age
# 18     1518.375000   2.500000     1.000        2.875000           3.000000
# 19     2075.000000   2.111111     1.000        2.444444           3.444444
# 20     2539.363636   2.636364     1.000        2.636364           3.000000
# 21     2491.461538   1.615385     1.000        2.692308           3.153846
# 22     2950.000000   1.812500     1.125        2.750000           3.250000
#
#      JobSatisfaction  EnvironmentSatisfaction  RelationshipSatisfaction  \
# Age
# 18          3.250000                 2.750000                  3.125000
# 19          2.555556                 2.444444                  2.888889
# 20          2.636364                 3.181818                  2.363636
# 21          2.692308                 2.692308                  2.692308
# 22          2.937500                 2.812500                  2.250000
#
#      WorkLifeBalance   DailyRate   MonthlyRate
# Age
# ...

# %%
age['Count']=df.Age.value_counts(dropna=False)
age.reset_index(level=0,inplace=True)
age.head()
# Out:
#    Age  MonthlyIncome  Education  JobLevel  JobInvolvement  PerformanceRating  \
# 0   18    1518.375000   2.500000     1.000        2.875000           3.000000
# 1   19    2075.000000   2.111111     1.000        2.444444           3.444444
# 2   20    2539.363636   2.636364     1.000        2.636364           3.000000
# 3   21    2491.461538   1.615385     1.000        2.692308           3.153846
# 4   22    2950.000000   1.812500     1.125        2.750000           3.250000
#
#    JobSatisfaction  EnvironmentSatisfaction  RelationshipSatisfaction  \
# 0         3.250000                 2.750000                  3.125000
# 1         2.555556                 2.444444                  2.888889
# 2         2.636364                 3.181818                  2.363636
# 3         2.692308                 2.692308                  2.692308
# 4         2.937500                 2.812500                  2.250000
#
#    WorkLifeBalance   DailyRate   MonthlyRate  Count
# ...

# %%
plt.figure(figsize=(20,5))
sns.barplot(age['Age'],age['Count'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(20,5))
plt.grid()
sns.barplot(age['Age'],age['MonthlyIncome'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='MonthlyIncome'>

# %%
income=pd.DataFrame(df.groupby("JobRole").MonthlyIncome.mean().sort_values(ascending=False))
income
# Out:
#                            MonthlyIncome
# JobRole
# Manager                     17181.676471
# Research Director           16033.550000
# Healthcare Representative    7528.763359
# Manufacturing Director       7295.137931
# Sales Executive              6924.279141
# Human Resources              4235.750000
# Research Scientist           3239.972603
# Laboratory Technician        3237.169884
# Sales Representative         2626.000000

# %%
income.index
# Out:
# Index(['Manager', 'Research Director', 'Healthcare Representative',
#        'Manufacturing Director', 'Sales Executive', 'Human Resources',
#        'Research Scientist', 'Laboratory Technician', 'Sales Representative'],
#       dtype='object', name='JobRole')

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.barplot(income.index,income['MonthlyIncome'])
# Out:
# C:\Users\AKSHY\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='JobRole', ylabel='MonthlyIncome'>

# %%
jobrole=pd.DataFrame(df.groupby("JobRole")["PercentSalaryHike","YearsAtCompany","TotalWorkingYears",
                                             "YearsInCurrentRole","WorkLifeBalance"].mean())
jobrole
# Out:
# <ipython-input-168-f84190de4351>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   jobrole=pd.DataFrame(df.groupby("JobRole")["PercentSalaryHike","YearsAtCompany","TotalWorkingYears",
#                            PercentSalaryHike  YearsAtCompany  \
# JobRole
# Healthcare Representative          15.450382        8.374046
# Human Resources                    14.807692        5.326923
# Laboratory Technician              15.046332        5.019305
# Manager                            15.137255       14.431373
# Manufacturing Director             15.593103        7.600000
# Research Director                  14.950000       10.937500
# Research Scientist                 15.448630        5.113014
# Sales Executive                    14.889571        7.496933
# Sales Representative               15.674699        2.915663
#
#                            TotalWorkingYears  YearsInCurrentRole  \
# JobRole
# ...

# %%
labels = df.EducationField.value_counts().index
labels
# Out:
# Index(['Life Sciences', 'Medical', 'Marketing', 'Technical Degree', 'Other',
#        'Human Resources'],
#       dtype='object')

# %%
size = df.EducationField.value_counts().values
size
# Out:
# array([606, 464, 159, 132,  82,  27], dtype=int64)

# %%
plt.figure(figsize=(20,10))
plt.pie(size,labels=labels,autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x24c50048490>,
# ...
#  [Text(0.2994329091618902, 1.0584611154458379, 'Life Sciences'),
#   Text(-0.9951095091219136, -0.4687825347164123, 'Medical'),
#   Text(0.2194966396897843, -1.0778781123878958, 'Marketing'),
#   Text(0.806357022319634, -0.7481900510938471, 'Technical Degree'),
#   Text(1.05386333339301, -0.315233365191208, 'Other'),
#   Text(1.09816922292375, -0.06343782643697085, 'Human Resources')],
#  [Text(0.16332704136103102, 0.5773424266068207, '41.2%'),
#   Text(-0.5427870049755892, -0.2556995643907703, '31.6%'),
#   Text(0.11972543983079142, -0.5879335158479431, '10.8%'),
#   Text(0.4398311030834367, -0.4081036642330074, '9.0%'),
#   Text(0.5748345454870963, -0.17194547192247708, '5.6%'),
#   Text(0.5990013943220454, -0.03460245078380227, '1.8%')])
